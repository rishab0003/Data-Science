# %%
import pandas as pd
df_boston = pd.read_csv('Boston House Prices.csv')
df_boston
# Out:
#      Rooms  Distance  Value
# 0    6.575    4.0900   24.0
# 1    6.421    4.9671   21.6
# 2    7.185    4.9671   34.7
# 3    6.998    6.0622   33.4
# 4    7.147    6.0622   36.2
# ..     ...       ...    ...
# 501  6.593    2.4786   22.4
# 502  6.120    2.2875   20.6
# 503  6.976    2.1675   23.9
# 504  6.794    2.3889   22.0
# 505  6.030    2.5050   11.9
#
# [506 rows x 3 columns]

# %% [markdown]
# # Multiple linear regression

# %%
import statsmodels.api as sm

# %% [markdown]
# # Define the dependent and independent variable

# %%
y = df_boston['Value'] # dependent variable
X = df_boston[['Rooms', 'Distance']] # independent variable

# %% [markdown]
# # Making the regression: Adding a constant and fitting the model

# %%
x = sm.add_constant(X) # adding a constant
lm = sm.OLS(y,X).fit() # fitting the model
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Value   R-squared (uncentered):                   0.903
# Model:                            OLS   Adj. R-squared (uncentered):              0.903
# Method:                 Least Squares   F-statistic:                              2349.
# Date:                Mon, 22 Dec 2025   Prob (F-statistic):                   3.41e-256
# Time:                        00:05:13   Log-Likelihood:                         -1742.5
# No. Observations:                 506   AIC:                                      3489.
# Df Residuals:                     504   BIC:                                      3497.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Rooms          3.3538      0.112     29.828      0.000       3.133       3.575
# Distance       0.4960      0.164      3.027      0.003       0.174       0.818
# ==============================================================================
# Omnibus:                      117.538   Durbin-Watson:                   0.518
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              257.138
# Skew:                           1.224   Prob(JB):                     1.46e-56
# Kurtosis:                       5.491   Cond. No.                         4.28
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

X = df_boston[['Rooms', 'Distance']]
y = df_boston['Value']

model = sm.OLS(y, X).fit()
y_pred = model.predict(X)

plt.figure()
plt.scatter(y, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()])
plt.xlabel("Actual Value")
plt.ylabel("Predicted Value")
plt.title("Actual vs Predicted Values (OLS Regression)")
plt.show()
