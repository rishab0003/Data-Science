# %%
import pandas as pd

# %%
df_exam = pd.read_csv('StudentsPerformance.csv')
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Adding a new column
# ## Adding a new column with a scalar value

# %%
df_exam['language score'] = 60
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                60
# 1                60
# 2                60
# 3                60
# 4                60
# ..              ...
# 995              60
# 996              60
# 997              60
# 998              60
# 999              60
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Adding a new column with an array

# %%
import numpy as np

# %%
language_score = np.arange(0,1000)

# %%
len(language_score)
# Out:
# 1000

# %%
df_exam['language score'] = language_score
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
int_language_score = np.random.randint(1,1000,size = 1000)

# %%
print(max(int_language_score))
print(min(int_language_score))
# Out:
# 998
# 1

# %%
df_exam['language score'] = int_language_score
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language score
# 0              65
# 1             134
# 2             822
# 3             560
# 4             327

# %%
# create random float numbers between 1 and 100
np.random.uniform(1,1000,size=1000)
# Out:
# array([176.39108464, 423.45938384, 625.16496496,  68.15616478,
#        564.6568614 , 809.53789041, 205.92052854, 457.59676321,
#        929.13777948, 296.95113174, 519.46941203, 698.44262486,
#        505.16195293, 999.27202131, 918.02088362, 728.82021362,
#         84.29680674, 722.04167995, 260.82704783, 848.1698966 ,
#        491.87983864, 453.29723343, 584.19159488, 688.32689568,
#        689.07921838, 840.04733752, 502.45723722, 227.26867891,
#        683.19124676, 339.56167935, 857.66323019, 607.72789063,
#        624.41218842,  14.85019472, 769.66474073, 642.5389844 ,
#        553.86691371, 673.3683199 , 822.70195193, 552.2185872 ,
#        654.2494793 ,  67.87538862, 553.86382694, 248.97520191,
#        967.23139421, 538.54017618, 268.16786961, 471.72057953,
#        444.04025333, 571.28805545, 222.0291048 , 227.86305926,
#         10.93069135, 552.21340435, 601.58195208, 890.50008627,
#        563.86862362, 282.68283955, 437.60063221,  60.46147208,
#         68.4982125 , 903.10934142, 444.93541441, 870.75403577,
#        687.50712645, 777.04550167, 742.9414644 , 117.50710733,
#        104.28068655, 667.00569804, 986.65126406, 594.07885494,
#        599.19805496,  94.60742671, 403.41693418, 566.7781835 ,
#        876.155004  , 407.20309406, 976.47081172, 209.85440493,
#        469.49278166, 199.69187518, 950.2473842 , 871.85002982,
#        562.92680598, 615.41648423, 200.95894452,  59.87406074,
#        335.82638684, 581.30525774, 326.4173939 , 883.65359936,
#        781.13619713,  90.88654443, 344.44363168, 325.20634322,
#        968.97286507, 439.35215491, 259.08203846, 481.64411961,
#        330.98100052, 904.23212429, 373.55905555, 288.44303169,
#        612.17113786, 864.42537074, 274.01086476, 606.25765488,
#        465.16957389, 542.64340577, 784.30634755, 873.39890847,
#        937.49156295,   3.6982466 , 829.00471198, 258.57004133,
#        733.35725767, 474.40688819, 516.93175397, 511.57476286,
#         52.72771704, 285.34625136, 302.73156852, 405.57007159,
#        532.01579217, 429.02275248, 408.88255643, 478.98244887,
#        423.37432323, 550.91940939, 813.33039773, 401.27050332,
#          7.28082064, 900.18803992,  96.28660344, 975.67727061,
#        596.40786336, 814.80222203, 365.41705981, 909.90543763,
#        454.57051103, 682.91943763, 466.10902969, 604.9152156 ,
#        149.71305387, 242.72982567, 804.68711183, 102.71299666,
#        338.51586304, 998.8090564 , 858.03647561,  99.9985596 ,
#        976.01276991, 879.55609657, 152.01836005, 711.42528137,
#          7.57676381, 606.52208743, 540.09479624, 427.81681713,
#        145.90054691,  55.15981685, 660.73117436,  18.08079392,
#        797.12081707, 532.10316409, 695.98324653, 259.25818772,
#        734.78863735, 801.16401938, 695.55239026, 851.24121137,
#        654.55673568, 904.35092076, 696.36915731, 380.26704584,
#        639.26723363, 308.89949429, 645.67585484, 125.55327971,
#        744.47971704, 675.10069485, 129.95426117, 141.53821225,
#        763.5902698 , 176.38900145, 485.94292484,  64.61463996,
#        740.77517653, 356.85494213, 679.98985971, 878.81936278,
#        178.17062484, 278.8631159 , 890.58336753, 828.8205432 ,
#        474.68279975, 564.50704635, 373.90296393, 916.99942712,
#         92.65378417, 890.31689415, 234.25635881,  63.39581244,
#        956.03414934, 698.06332174, 354.9940656 , 433.86634633])

# %% [markdown]
# # Add New Column with assign() and insert()

# %% [markdown]
# ## assign()
# When to use assign?
#
# Add multiple columns in a single line of code.
# When you need to overwrite the values of an existing columns (best practice).
# It returns a new object (a copy) with all the original columns in addition to the new ones.

# %%
score1 = np.random.randint(1,100,size=1000)
score2 = np.random.randint(1,100,size=1000)

# %%
series1 = pd.Series(score1,index=np.arange(0,1000))
series2 = pd.Series(score2,index=np.arange(0,1000))

# %%
df_exam = df_exam.assign(score1=series1, score2=series2)
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language score  score1  score2
# 0              65      89      68
# 1             134      87      19
# 2             822      54      68
# 3             560       3      58
# 4             327      20      88

# %% [markdown]
# # insert()
# Inserts a new column at a specific position or index.

# %%
# using insert() to add a column at a specific position
df_exam.insert(1, 'test', series1)
df_exam
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    89        group B           bachelor's degree      standard
# 1    female    87        group C                some college      standard
# 2    female    54        group B             master's degree      standard
# 3      male     3        group A          associate's degree  free/reduced
# 4      male    20        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    47        group E             master's degree      standard
# 996    male     2        group C                 high school  free/reduced
# 997  female    67        group C                 high school  free/reduced
# 998  female     7        group D                some college      standard
# 999  female    69        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                65      89      68
# 1               134      87      19
# 2               822      54      68
# 3               560       3      58
# 4               327      20      88
# ..              ...     ...     ...
# 995             254      47      58
# 996             466       2      13
# 997             471      67      97
# 998             860       7      82
# 999             829      69      67
#
# [1000 rows x 12 columns]
