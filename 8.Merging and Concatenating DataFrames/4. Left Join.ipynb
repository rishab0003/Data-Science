# %%
import pandas as pd
df_movies = pd.read_csv('IMDb movies.csv',low_memory=False)
df_ratings = pd.read_csv('IMDb ratings.csv')

# %%
# select columns
df_movies = df_movies[['imdb_title_id', 'title', 'year',
                       'genre', 'country', 'director', 'actors']]

df_ratings = df_ratings[['imdb_title_id', 'total_votes', 'mean_vote']]

# %% [markdown]
# # merge()

# %%
df1 = pd.DataFrame({'id': ['A', 'B', 'C', 'D'],
                    'age': [30, 23, 25, 22]})
df2 = pd.DataFrame({'id': ['C', 'D', 'E', 'F'],
                    'job': ['Doctor', 'Statistician',
                            'Accountant', 'Developer']})

# %% [markdown]
# # Left join

# %%
df1.merge(df2, on='id', how='left')
# Out:
#   id  age           job
# 0  A   30           NaN
# 1  B   23           NaN
# 2  C   25        Doctor
# 3  D   22  Statistician

# %% [markdown]
# # Exercise

# %%
# extract a 50% sample of the df_movies dataframe
df_sample = df_movies.sample(frac=0.5)

# %%
# merge df_sample and df_ratings (left join)
df_sm = df_sample.merge(df_ratings, on = 'imdb_title_id', how='left')

# %%
# shape
df_sm.shape
# Out:
# (42928, 9)

# %% [markdown]
# # Exclusive Left join

# %%
# indicator=True
df1.merge(df2, on='id', how='outer',
          indicator = True)
# Out:
#   id   age           job      _merge
# 0  A  30.0           NaN   left_only
# 1  B  23.0           NaN   left_only
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
#query
df1.merge(df2, on='id', how='outer',
          indicator=True).query("_merge=='left_only'")
# Out:
#   id   age  job     _merge
# 0  A  30.0  NaN  left_only
# 1  B  23.0  NaN  left_only

# %%
# left join
pd.merge(df_movies, df_ratings.sample(frac=.5),
         on='imdb_title_id', how='left').shape
# Out:
# (85855, 9)

# %% [markdown]
# # Exercise

# %%
# make a copy of the df_movies dataframe
df_movies_copy = df_movies.copy()

# %%
# set the first 1000 values of 'imdb_title_id' column as 'tt1234567890'
df_movies.loc[:999, 'imdb_title_id'] = 'tt1234567890'

# %%
# merge df_movies_copy and df_ratings (exclusive left join)
df_left_only = df_movies_copy.merge(df_ratings, on='imdb_title_id', how='left',
                     indicator=True).query("_merge=='left_only'")

# %%
# shape
df_left_only.shape
# Out:
# (1000, 10)

# %%
df_left_only
# Out:
#     imdb_title_id                        title  year  \
# 0    tt1234567890                   Miss Jerry  1894
# 1    tt1234567890  The Story of the Kelly Gang  1906
# 2    tt1234567890               Den sorte drøm  1911
# 3    tt1234567890                    Cleopatra  1912
# 4    tt1234567890                    L'Inferno  1911
# ..            ...                          ...   ...
# 995  tt1234567890            Agente segreto Z1  1930
# 996  tt1234567890                   Tom Sawyer  1930
# 997  tt1234567890               Tonka Sibenice  1930
# 998  tt1234567890                    Top Speed  1930
# 999  tt1234567890             True to the Navy  1930
#
#                          genre                  country  \
# 0                      Romance                      USA
# 1      Biography, Crime, Drama                Australia
# 2                        Drama         Germany, Denmark
# 3               Drama, History                      USA
# 4    Adventure, Drama, Fantasy                    Italy
# ..                         ...                      ...
# 995                      Drama                      USA
# 996   Adventure, Comedy, Drama                      USA
# 997                      Drama  Czechoslovakia, Germany
# 998   Comedy, Musical, Romance                      USA
# 999    Action, Comedy, Romance                      USA
#
#                                 director  \
# 0                        Alexander Black
# 1                           Charles Tait
# 2                              Urban Gad
# 3                     Charles L. Gaskill
# 4    Francesco Bertolini, Adolfo Padovan
# ..                                   ...
# 995                         Roy Del Ruth
# 996                        John Cromwell
# 997                           Karl Anton
# 998                         Mervyn LeRoy
# 999                         Frank Tuttle
#
#                                                 actors  total_votes  \
# 0    Blanche Bayliss, William Courtenay, Chauncey D...          NaN
# 1    Elizabeth Tait, John Tait, Norman Campbell, Be...          NaN
# 2    Asta Nielsen, Valdemar Psilander, Gunnar Helse...          NaN
# 3    Helen Gardner, Pearl Sindelar, Miss Fielding, ...          NaN
# 4    Salvatore Papa, Arturo Pirovano, Giuseppe de L...          NaN
# ..                                                 ...          ...
# 995  Constance Bennett, Erich von Stroheim, Anthony...          NaN
# 996  Jackie Coogan, Junior Durkin, Mitzi Green, Luc...          NaN
# 997  Ita Rina, Vera Baranovskaya, Josef Rovenský, A...          NaN
# 998  Joe E. Brown, Bernice Claire, Jack Whiting, Fr...          NaN
# 999  Clara Bow, Fredric March, Harry Green, Rex Bel...          NaN
#
#      mean_vote     _merge
# 0          NaN  left_only
# 1          NaN  left_only
# 2          NaN  left_only
# 3          NaN  left_only
# 4          NaN  left_only
# ..         ...        ...
# 995        NaN  left_only
# 996        NaN  left_only
# 997        NaN  left_only
# 998        NaN  left_only
# 999        NaN  left_only
#
# [1000 rows x 10 columns]
