# %%
import pandas as pd
df_movies = pd.read_csv('IMDb movies.csv',low_memory=False)
df_ratings = pd.read_csv('IMDb ratings.csv')

# %%
# select columns
df_movies = df_movies[['imdb_title_id', 'title', 'year',
                       'genre', 'country', 'director', 'actors']]

df_ratings = df_ratings[['imdb_title_id', 'total_votes', 'mean_vote']]

# %% [markdown]
# # merge()

# %%
df1 = pd.DataFrame({'id': ['A', 'B', 'C', 'D'],
                    'age': [30, 23, 25, 22]})
df2 = pd.DataFrame({'id': ['C', 'D', 'E', 'F'],
                    'job': ['Doctor', 'Statistician',
                            'Accountant', 'Developer']})

# %%
df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2
# Out:
#   id           job
# 0  C        Doctor
# 1  D  Statistician
# 2  E    Accountant
# 3  F     Developer

# %% [markdown]
# # Inner join

# %%
df1.merge(df2, on='id', how='inner')
# Out:
#   id  age           job
# 0  C   25        Doctor
# 1  D   22  Statistician

# %%
# shape
print(df1.shape)
print(df2.shape)
print(df1.merge(df2, on='id', how='inner').shape)
# Out:
# (4, 2)
# (4, 2)
# (2, 3)

# %% [markdown]
# ### Exercise

# %%
# merge df_movies and df_ratings (inner join)
df_movies.merge(df_ratings,on='imdb_title_id',how='inner')
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  \
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# 4      Adventure, Drama, Fantasy             Italy
# ...                          ...               ...
# 85850                     Comedy   France, Belgium
# 85851              Comedy, Drama       Netherlands
# 85852                      Drama             India
# 85853              Drama, Family            Turkey
# 85854                      Drama             Spain
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 85850               Ludovic Colbeau-Justin
# 85851                      Johan Nijenhuis
# 85852                      Vineesh Aaradya
# 85853                    Ahmet Faik Akinci
# 85854                            Laura Jou
#
#                                                   actors  total_votes  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...          154
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...          589
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...          188
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...          446
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...         2237
# ...                                                  ...          ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...          398
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...          724
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...          265
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...          194
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...          102
#
#        mean_vote
# 0            5.9
# 1            6.3
# 2            6.0
# 3            5.3
# 4            6.9
# ...          ...
# 85850        5.5
# 85851        7.9
# 85852        7.8
# 85853        9.4
# 85854        6.8
#
# [85855 rows x 9 columns]

# %%
df_movies.merge(df_ratings,on='imdb_title_id',how='inner').shape
# Out:
# (85855, 9)
