# %% [markdown]
# # Barplot grouped by “n” variables

# %%
pip install cufflinks
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.9.2 in /usr/lib64/python3.14/site-packages (from cufflinks) (2.3.5)
# Requirement already satisfied: pandas>=0.19.2 in /usr/lib64/python3.14/site-packages (from cufflinks) (2.3.3)
# Collecting plotly>=4.1.1 (from cufflinks)
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3.14/site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Requirement already satisfied: setuptools>=34.4.1 in /usr/lib/python3.14/site-packages (from cufflinks) (78.1.1)
# Requirement already satisfied: ipython>=5.3.0 in /usr/lib/python3.14/site-packages (from cufflinks) (8.37.0)
# Collecting ipywidgets>=7.0.0 (from cufflinks)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: decorator in /usr/lib/python3.14/site-packages (from ipython>=5.3.0->cufflinks) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /usr/lib/python3.14/site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/lib/python3.14/site-packages (from ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3.14/site-packages (from ipython>=5.3.0->cufflinks) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/lib/python3.14/site-packages (from ipython>=5.3.0->cufflinks) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3.14/site-packages (from ipython>=5.3.0->cufflinks) (2.19.1)
# Requirement already satisfied: stack_data in /usr/lib/python3.14/site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/lib/python3.14/site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: wcwidth in /usr/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in /usr/lib/python3.14/site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=7.0.0->cufflinks)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets>=7.0.0->cufflinks)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/lib/python3.14/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.14/site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3.14/site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/lib/python3.14/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Collecting narwhals>=1.15.1 (from plotly>=4.1.1->cufflinks)
#   Using cached narwhals-2.13.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/lib/python3.14/site-packages (from plotly>=4.1.1->cufflinks) (25.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/lib/python3.14/site-packages (from stack_data->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/lib/python3.14/site-packages (from stack_data->ipython>=5.3.0->cufflinks) (3.0.0)
# Requirement already satisfied: pure_eval in /usr/lib/python3.14/site-packages (from stack_data->ipython>=5.3.0->cufflinks) (0.2.3)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 1.2 MB/s eta 0:00:00995.0 kB/s eta 0:00:01
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.1 MB/s eta 0:00:001.9 MB/s eta 0:00:01
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 4.5 MB/s eta 0:00:000:00:01m eta 0:00:01
# Using cached narwhals-2.13.0-py3-none-any.whl (426 kB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml) ... done
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=67768 sha256=1a5b2dca3ee57e5e6b33f8f0dbffbcc8a979bad13145492b3f284d35447a33bc
#   Stored in directory: /home/rishab/.cache/pip/wheels/e4/0d/21/3611484024347032ee330271868478a2c28877581eb01f9b79
# Successfully built cufflinks
# Installing collected packages: colorlover, widgetsnbextension, narwhals, jupyterlab_widgets, plotly, ipywidgets, cufflinks
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [cufflinks]━ 6/7 [cufflinks]tly]
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3 ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 narwhals-2.13.0 plotly-6.5.0 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import cufflinks as cf
from IPython.display import display, HTML

cf.set_config_file(sharing='public', theme='ggplot', offline=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 import cufflinks as cf
#       3 from IPython.display import display, HTML
#       5 cf.set_config_file(sharing='public', theme='ggplot', offline=True)
#
# ModuleNotFoundError: No module named 'cufflinks'
