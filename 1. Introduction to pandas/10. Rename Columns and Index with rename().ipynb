# %%
import pandas as pd
df_exam = pd.read_csv('StudentsPerformance.csv')
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## Rename Column

# %%
# rename column and overwrite values of the dataframe
df_exam = df_exam.rename(columns={'lunch':'LUNCH'})

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         LUNCH  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# rename multiple columns and update the dataframe with inplace parameter
df_exam.rename(columns={'gender':'GENDER','math score':'Maths Score'}, inplace=True)

# %%
df_exam.head()
# Out:
#    GENDER race/ethnicity parental level of education         LUNCH  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  Maths Score  reading score  writing score
# 0                    none           72             72             74
# 1               completed           69             90             88
# 2                    none           90             95             93
# 3                    none           47             57             44
# 4                    none           76             78             75

# %%
df_exam.rename(index={0:'A',1:'B',2:'C'},inplace=True)
df_exam.head(3)
# Out:
#    GENDER race/ethnicity parental level of education     LUNCH  \
# A  female        group B           bachelor's degree  standard
# B  female        group C                some college  standard
# C  female        group B             master's degree  standard
#
#   test preparation course  Maths Score  reading score  writing score
# A                    none           72             72             74
# B               completed           69             90             88
# C                    none           90             95             93
